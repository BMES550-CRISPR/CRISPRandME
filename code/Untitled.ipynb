# %%
import pandas as pd

# %%
df = pd.read_csv('../raw_data/sample_individuals_ALL_v2.20130502.tsv', sep='\t')
df.head()
# Out:
#   Family ID Individual ID Paternal ID Maternal ID  Gender  Phenotype  \
# 0   HG00096       HG00096           0           0       1          0
# 1   HG00097       HG00097           0           0       2          0
# 2   HG00098       HG00098           0           0       1          0
# 3   HG00099       HG00099           0           0       2          0
# 4   HG00100       HG00100           0           0       2          0
#
#   Population Relationship Siblings Second Order Third Order Children  \
# 0        GBR        unrel        0            0           0        0
# 1        GBR        unrel        0            0           0        0
# 2        GBR        unrel        0            0           0        0
# 3        GBR        unrel        0            0           0        0
# 4        GBR        unrel        0            0           0        0
#
#   Other Comments  phase 3 genotypes  related genotypes  omni genotypes  \
# ...

# %%
(df['phase 3 genotypes']==1).sum()
# Out:
# 2504
